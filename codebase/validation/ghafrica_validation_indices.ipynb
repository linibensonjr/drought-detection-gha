# %%
import os
import time
import rasterio
import pickle
import numpy as np
import pandas as pd
import xarray as xr
import seaborn as sns
import datetime as dt
import rioxarray as rxr
import geopandas as gpd
import matplotlib.pyplot as plt
from scipy.stats import kendalltau
from pandas import date_range, to_datetime
import dask
import dask.dataframe as dd
import matplotlib.dates as mdates
import logging
import dask.array as da
from joblib import Parallel, delayed
from dask import config as dask_config
from dask.diagnostics import ProgressBar
import warnings
import subprocess

# %%
dataset = '../../../datasets/'
variables = xr.open_dataset(os.path.join(dataset, 'processed_final_data/daily_dataset'), chunks={'time': 500, 'y': 175, 'x': 148})

# %%
output_dir = '../../../datasets/validation_datasets/precip'
index_output = '../../../datasets/validation_datasets/index-spi'

# %%
spi_30 = xr.open_dataset(os.path.join(index_output, 'index-spi_spi_gamma_30.nc'))
spi_90 = xr.open_dataset(os.path.join(index_output, 'index-spi_spi_gamma_90.nc'))
spi_180 = xr.open_dataset(os.path.join(index_output, 'index-spi_spi_gamma_180.nc'))
spi_360 = xr.open_dataset(os.path.join(index_output, 'index-spi_spi_gamma_360.nc'))

# %%
print(spi_90)
# Out:
# <xarray.Dataset>
# Dimensions:       (lon: 207, lat: 360, time: 7671)
# Coordinates:
#     band          int64 ...
#     x             (lon) float64 ...
#     y             (lat) float64 ...
#   * time          (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref   int64 ...
#   * lat           (lat) float64 17.62 17.57 17.37 17.32 ... -9.775 -9.875 -9.925
#   * lon           (lon) float64 24.23 24.28 24.33 24.38 ... 42.68 42.73 47.28
# Data variables:
#     spi_gamma_90  (lat, lon, time) float64 ...

# %%
print(variables)
# Out:
# <xarray.Dataset>
# Dimensions:        (x: 591, y: 698, time: 7671)
# Coordinates:
#     band           int64 ...
#   * x              (x) float64 21.88 21.93 21.98 22.03 ... 51.28 51.33 51.38
#   * y              (y) float64 23.12 23.07 23.02 22.97 ... -11.63 -11.68 -11.73
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 ...
#     lat            (y) float64 dask.array<chunksize=(175,), meta=np.ndarray>
#     lon            (x) float64 dask.array<chunksize=(148,), meta=np.ndarray>
# Data variables:
#     precipitation  (time, y, x) float32 dask.array<chunksize=(500, 175, 148), meta=np.ndarray>
#     et             (time, y, x) float64 dask.array<chunksize=(500, 175, 148), meta=np.ndarray>
#     sm             (time, y, x) float64 dask.array<chunksize=(500, 175, 148), meta=np.ndarray>
#     tws            (time, y, x) float64 dask.array<chunksize=(500, 175, 148), meta=np.ndarray>
#     landform       (y, x) float64 dask.array<chunksize=(175, 148), meta=np.ndarray>

# %%
# Define SMA function
def compute_sma(da, window, dim='time'):
    logging.info(f"Computing SMA for window {window} along dimension {dim}")
    return da.rolling(time=window, center=False).mean()

# %% [markdown]
# #### Precocess the subregions

# %%
start = time.time()
landform_classes = np.unique(variables['landform'].values[~np.isnan(variables['landform'].values)])
print('Extracted Landform classes')

# Dictionary to store subregion datasets
subregion_datasets = {}

# Loop through each subregion
for subregion_id in landform_classes:
    if np.isnan(subregion_id): 
        continue
    # Mask the combined dataset where landform matches the subregion ID
    subregion_mask = variables['landform'] == subregion_id
    subregion_ds = variables.where(subregion_mask, drop=True)
    print(f"Completed subregion {int(subregion_id)} ")
    subregion_datasets[int(subregion_id)] = subregion_ds

# Example: Access subregion 1
print("Subregion 1 dataset:")
print(subregion_datasets[1])
# Inspect combined dataset

end = time.time()
# Out:
# Extracted Landform classes
# Completed subregion 1
# Completed subregion 2
# Completed subregion 3
# Completed subregion 4
# Completed subregion 5
# Completed subregion 6
# Completed subregion 7
# Completed subregion 8
# Completed subregion 9
# Subregion 1 dataset:
# <xarray.Dataset>
# Dimensions:        (time: 7671, y: 671, x: 337)
# Coordinates:
#     band           int64 1
#   * x              (x) float64 30.33 30.38 30.48 30.53 ... 51.28 51.33 51.38
#   * y              (y) float64 23.12 23.07 23.02 22.97 ... -11.28 -11.33 -11.38
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 0
#     lat            (y) float64 dask.array<chunksize=(172,), meta=np.ndarray>
#     lon            (x) float64 dask.array<chunksize=(44,), meta=np.ndarray>
# Data variables:
#     precipitation  (time, y, x) float32 dask.array<chunksize=(500, 172, 44), meta=np.ndarray>
#     et             (time, y, x) float64 dask.array<chunksize=(500, 172, 44), meta=np.ndarray>
#     sm             (time, y, x) float64 dask.array<chunksize=(500, 172, 44), meta=np.ndarray>
#     tws            (time, y, x) float64 dask.array<chunksize=(500, 172, 44), meta=np.ndarray>
#     landform       (y, x) float64 dask.array<chunksize=(172, 44), meta=np.ndarray>

# %% [markdown]
# ##### Extract the Precipitation variables

# %%
for subregion in precipitation_var.keys():
    print(f'Saving {subregion}...')
    precipitation_var[subregion].to_netcdf(os.path.join(f'{output_dir}_{subregion}.nc'))
# Out:
# Saving subregion_1...
# Saving subregion_2...
# Saving subregion_3...
# Saving subregion_4...
# Saving subregion_5...
# Saving subregion_6...
# Saving subregion_7...
# Saving subregion_8...
# Saving subregion_9...

# %%
# !which process_climate_indices
# Out:
# /home/jovyan/.local/bin/process_climate_indices

# %%
start = time.time()

# Get unique landform classes excluding NaNs
landform_classes = np.unique(variables['landform'].values[~np.isnan(variables['landform'].values)])
print('Extracted Landform classes')

# Dictionary to store subregion datasets
subregion_datasets = {}

# Loop through each subregion
for subregion_id in landform_classes:
    # Mask the dataset
    subregion_mask = variables['landform'] == subregion_id
    subregion_ds = variables.where(subregion_mask, drop=True)

    # Drop other variables, rename dimensions
    subregion_precip = subregion_ds[['precipitation']]\
        .swap_dims({'y': 'lat', 'x': 'lon'})\
        .transpose('lat', 'lon', 'time')

    # Store in dictionary
    subregion_datasets[int(subregion_id)] = subregion_precip

    # Save to NetCDF
    filename = os.path.join(output_dir, f'subregion_{int(subregion_id)}.nc')
    subregion_precip.to_netcdf(filename)

    print(f"Completed subregion {int(subregion_id)}")

# Example: Access subregion 1
print("Subregion 1 dataset:")
print(subregion_datasets[1])

end = time.time()
print(f"Finished in {end - start:.2f} seconds.")
# Out:
# Extracted Landform classes
# Completed subregion 1
# Completed subregion 2
# Completed subregion 3
# Completed subregion 4
# Completed subregion 5
# Completed subregion 6
# Completed subregion 7
# Completed subregion 8
# Completed subregion 9
# Subregion 1 dataset:
# <xarray.Dataset>
# Dimensions:        (time: 7671, lat: 671, lon: 337)
# Coordinates:
#     band           int64 1
#     x              (lon) float64 30.33 30.38 30.48 30.53 ... 51.28 51.33 51.38
#     y              (lat) float64 23.12 23.07 23.02 ... -11.28 -11.33 -11.38
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 0
#   * lat            (lat) float64 23.12 23.07 23.02 ... -11.28 -11.33 -11.38
#   * lon            (lon) float64 30.33 30.38 30.48 30.53 ... 51.28 51.33 51.38
# Data variables:
#     precipitation  (lat, lon, time) float32 dask.array<chunksize=(172, 44, 500), meta=np.ndarray>
# Finished in 6394.77 seconds.

# %%
subregion_datasets[9].dims
# Out:
# Frozen({'time': 7671, 'lat': 360, 'lon': 207})

# %%
sorted(os.listdir(output_dir).endswith('.nc'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 sorted(os.listdir(output_dir).endswith('.nc'))
#
# AttributeError: 'list' object has no attribute 'endswith'

# %%
precip_data = {}
for subre in sorted(os.listdir(output_dir)):
    if subre.endswith('.nc'):
        precip_data[subre.strip('precip_')] = xr.open_dataset(os.path.join(output_dir, subre))
    else:
        print(f'Skipping {subre}...')# subre.close()
    
print(precip_data)
# Out:
# Skipping .ipynb_checkpoints...
# Skipping .nfs0000000000037f58000005c4...
# Skipping .nfs00000000000384c2000005bf...
# Skipping .nfs0000000000038b2f000005be...
# Skipping .nfs0000000000038db9000005c5...
# Skipping .nfs00000000000390a8000005c2...
# Skipping .nfs000000000003911b000005c0...
# Skipping .nfs00000000000392be000005c1...
# Skipping .nfs0000000000039361000005c3...
# Skipping .nfs0000000000039763000005c6...
# {'subregion_1.n': <xarray.Dataset>
# Dimensions:        (time: 7671, lat: 671, lon: 337)
# Coordinates:
#     band           int64 ...
#     x              (lon) float64 ...
#     y              (lat) float64 ...
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 ...
#   * lat            (lat) float64 23.12 23.07 23.02 ... -11.28 -11.33 -11.38
#   * lon            (lon) float64 30.33 30.38 30.48 30.53 ... 51.28 51.33 51.38
# Data variables:
#     precipitation  (time, lat, lon) float32 ..., 'subregion_2.n': <xarray.Dataset>
# Dimensions:        (time: 7671, lat: 686, lon: 543)
# Coordinates:
#     band           int64 ...
#     x              (lon) float64 ...
#     y              (lat) float64 ...
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 ...
#   * lat            (lat) float64 22.87 22.82 22.77 ... -11.63 -11.68 -11.73
#   * lon            (lon) float64 23.28 23.33 23.38 23.43 ... 50.88 50.93 50.98
# Data variables:
#     precipitation  (time, lat, lon) float32 ..., 'subregion_3.n': <xarray.Dataset>
# Dimensions:        (time: 7671, lat: 689, lon: 575)
# Coordinates:
#     band           int64 ...
#     x              (lon) float64 ...
#     y              (lat) float64 ...
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 ...
#   * lat            (lat) float64 22.77 22.72 22.67 ... -11.53 -11.58 -11.63
#   * lon            (lon) float64 21.88 21.93 21.98 22.03 ... 50.48 50.58 50.63
# Data variables:
#     precipitation  (time, lat, lon) float32 ..., 'subregion_4.n': <xarray.Dataset>
# Dimensions:        (time: 7671, lat: 692, lon: 589)
# Coordinates:
#     band           int64 ...
#     x              (lon) float64 ...
#     y              (lat) float64 ...
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 ...
#   * lat            (lat) float64 22.92 22.87 22.82 ... -11.58 -11.63 -11.68
#   * lon            (lon) float64 21.88 21.98 22.03 22.08 ... 51.23 51.28 51.33
# Data variables:
#     precipitation  (time, lat, lon) float32 ..., 'subregion_5.n': <xarray.Dataset>
# Dimensions:        (time: 7671, lat: 576, lon: 475)
# Coordinates:
#     band           int64 ...
#     x              (lon) float64 ...
#     y              (lat) float64 ...
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 ...
#   * lat            (lat) float64 18.92 18.87 18.82 ... -11.23 -11.28 -11.33
#   * lon            (lon) float64 22.23 22.33 22.38 22.43 ... 50.03 50.08 50.78
# Data variables:
#     precipitation  (time, lat, lon) float32 ..., 'subregion_6.n': <xarray.Dataset>
# Dimensions:        (time: 7671, lat: 384, lon: 230)
# Coordinates:
#     band           int64 ...
#     x              (lon) float64 ...
#     y              (lat) float64 ...
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 ...
#   * lat            (lat) float64 17.52 17.47 17.37 ... -9.875 -9.925 -9.975
#   * lon            (lon) float64 24.28 24.33 24.38 28.98 ... 47.38 47.43 47.48
# Data variables:
#     precipitation  (time, lat, lon) float32 ..., 'subregion_7.n': <xarray.Dataset>
# Dimensions:        (time: 7671, lat: 658, lon: 534)
# Coordinates:
#     band           int64 ...
#     x              (lon) float64 ...
#     y              (lat) float64 ...
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 ...
#   * lat            (lat) float64 22.77 22.72 22.67 ... -11.53 -11.58 -11.68
#   * lon            (lon) float64 22.18 22.28 22.33 22.48 ... 51.13 51.18 51.23
# Data variables:
#     precipitation  (time, lat, lon) float32 ..., 'subregion_8.n': <xarray.Dataset>
# Dimensions:        (time: 7671, lat: 645, lon: 480)
# Coordinates:
#     band           int64 ...
#     x              (lon) float64 ...
#     y              (lat) float64 ...
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 ...
#   * lat            (lat) float64 22.67 22.22 22.17 ... -11.43 -11.48 -11.53
#   * lon            (lon) float64 22.38 22.73 22.98 23.13 ... 50.68 50.73 50.83
# Data variables:
#     precipitation  (time, lat, lon) float32 ..., 'subregion_9.n': <xarray.Dataset>
# Dimensions:        (time: 7671, lat: 360, lon: 207)
# Coordinates:
#     band           int64 ...
#     x              (lon) float64 ...
#     y              (lat) float64 ...
#   * time           (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref    int64 ...
#   * lat            (lat) float64 17.62 17.57 17.37 ... -9.775 -9.875 -9.925
#   * lon            (lon) float64 24.23 24.28 24.33 24.38 ... 42.68 42.73 47.28
# Data variables:
#     precipitation  (time, lat, lon) float32 ...}

# %%
# Calculate SPI at 1, 3, 6 and 12 months timescales
start = time.time()
for subregion in sorted(os.listdir(output_dir)):
    if subregion.endswith('.nc'):
        subregion_file = os.path.join(output_dir, subregion)
        print(f'Processing SPI for {subregion}...')
        try:
    
            cmd = [
                "process_climate_indices",
                "--index", "spi",
                "--periodicity", "daily",
                "--netcdf_precip", f"{subregion_file}",
                "--var_name_precip", "precipitation",
                "--output_file_base", f"{index_output}",
                "--scales", "30", "90", "180", "360",
                "--calibration_start_year", "2004",
                "--calibration_end_year", "2024",
                "--multiprocessing", "all"
            ]
            result = subprocess.run(cmd, capture_output=True, text=True)
            # Show output
            print(result.stdout)
            print(result.stderr)
        
        except Exception as e:
            print(f"An error occurred: {e}")
            pass

end = time.time()
print(f'Completed in {end - start:2f} seconds')
# Out:
# Processing SPI for subregion_1.nc...
#
# 2025-05-14  00:35:58 INFO Start time:    2025-05-14 00:35:58.391602
# 2025-05-14  00:36:02 INFO Computing 30-day SPI/Pearson
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# 2025-05-14  00:41:55 INFO Computing 30-day SPI/Gamma
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# 2025-05-14  00:46:28 INFO Computing 90-day SPI/Pearson
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
# ...
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# 2025-05-14  06:23:37 INFO Computing 90-day SPI/Pearson
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# 2025-05-14  06:25:32 INFO Computing 90-day SPI/Gamma
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:707: RuntimeWarning: Mean of empty slice
#   means = np.nanmean(calibration_values, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:710: RuntimeWarning: Mean of empty slice
#   mean_logs = np.nanmean(logs, axis=0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:712: RuntimeWarning: divide by zero encountered in divide
#   alphas = (1 + np.sqrt(1 + 4 * a / 3)) / (4 * a)
# /home/jovyan/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# 2025-05-14  06:27:04 INFO Computing 180-day SPI/Pearson
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# 2025-05-14  06:28:49 INFO Computing 180-day SPI/Gamma
# 2025-05-14  06:30:20 INFO Computing 360-day SPI/Pearson
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:455: RuntimeWarning: divide by zero encountered in divide
#   alpha = 4.0 / (skew * skew)
# /home/jovyan/.local/lib/python3.8/site-packages/climate_indices/compute.py:459: RuntimeWarning: invalid value encountered in multiply
#   return loc - ((alpha * scale * skew) / 2.0)
# 2025-05-14  06:31:53 INFO Computing 360-day SPI/Gamma
# 2025-05-14  06:33:26 INFO End time:      2025-05-14 06:33:26.785813
# 2025-05-14  06:33:26 INFO Elapsed time:  0:13:03.758925
#
# Completed in 21454.929471 seconds

# %%
print(spi_90)
# Out:
# <xarray.Dataset>
# Dimensions:       (lon: 207, lat: 360, time: 7671)
# Coordinates:
#     band          int64 ...
#     x             (lon) float64 ...
#     y             (lat) float64 ...
#   * time          (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2024-12-31
#     spatial_ref   int64 ...
#   * lat           (lat) float64 17.62 17.57 17.37 17.32 ... -9.775 -9.875 -9.925
#   * lon           (lon) float64 24.23 24.28 24.33 24.38 ... 42.68 42.73 47.28
# Data variables:
#     spi_gamma_90  (lat, lon, time) float64 ...

# %%
plt.figure(figsize=(20,8))
compute_sma(spi_90.spi_gamma_90, 30).sel(lat=11.46, lon= 37.72, method='nearest').plot(label='p-et_3month')
spi_90.spi_gamma_90.sel(lat=11.46, lon= 37.72, method='nearest').plot(label='p-et_3month')
# zone_1.et_90.sel(y=0.46, x= 41.72, method='nearest').plot(label='p-et_3month')
# zone_1.pet_90.sel(y=0.46, x= 41.72, method='nearest').plot(label='p-et_3month')

# %%
spi_90.spi_gamma_90.isel(time=361).plot()

# %%
plt.figure(figsize=(20,8))
ds_standardized[360]['pet_360'].sel(y=0, x= 41.72, method='nearest').plot(label='p-et_3month')
ds_standardized[360]['sm_360'].sel(y=0, x= 41.72, method='nearest').plot(label='sm_3month')
ds_standardized[360]['tws_ds'].sel(y=0, x= 41.72, method='nearest').plot(label='tws_3month')
plt.axhline(0, color='k', linestyle='--')
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.show()
