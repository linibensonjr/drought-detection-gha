# %%
# import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %%
import rasterio

# %%
# Read LSA Et dataset

file = r'..\data\lsa_et\NETCDF4_LSASAF_MSG_ETv3_MSG-Disk_200401211000.nc'

# %%
# Open and display

ile_open = xr.open_dataset(file)
file_open
# Out:
# <xarray.Dataset> Size: 164MB
# Dimensions:       (time: 1, lat: 3201, lon: 3201)
# Coordinates:
#   * lat           (lat) float32 13kB 80.0 79.95 79.9 ... -79.9 -79.95 -80.0
#   * lon           (lon) float32 13kB -80.0 -79.95 -79.9 ... 79.9 79.95 80.0
#   * time          (time) datetime64[ns] 8B 2004-01-21T10:00:00
# Data variables:
#     ET            (time, lat, lon) float64 82MB ...
#     crs           |S1 1B ...
#     quality_flag  (time, lat, lon) float64 82MB ...
# Attributes: (12/27)
#     date_created:               2022-03-28T10:51:03Z
#     algorithm_version:          2.0.0
#     base_algorithm_version:     5.0.7
#     processing_level:           04
#     platform:                   MSG1
#     sensor:                     SEVI
#     ...                         ...
#     westernmost_longitude:      80.0
#     spatial_resolution:          0.05x 0.05
#     geospatial_lat_units:       degrees_north
#     geospatial_lon_units:       degrees_east
# ...

# %%
et = file_open['ET']

# %%
et.isel(time=0).plot()
plt.title('ET in January')
# Out:
# Text(0.5, 1.0, 'ET in January')

# %%
# ET at a location in GHA

loc = et.sel(lat=5.34, lon=10.34, method='nearest')

(loc.values)
# Out:
# array([0.2495])
